# %% [markdown]
# # 👨🏾‍💻 Estudos Python

# %%
lista = ["Brasil", "Itabuna", "Bahia"]

lista.append("New CIty") # Adiciona um item ao final de uma lista
print(lista)

lista.insert(0, "America") # Insere na lista na posição especifica
print(lista)

lista.pop(0) # Remove o item da lista na posição especifica
print(lista)

print("tamanho =", len(lista)) # Mostra o tam da lista,  qtde de itens na lista

print("tamanho =", len("Python")) # qtde de caractere

# %% [markdown]
# #### 📝 Anotações
#
# *    *len() significa length e, quando usado em listas, retorna o número de itens na lista, e strings o número de caracteres*
#
# *   *A função append() adiciona um novo item ao final de uma lista. é chamado usando a notação de ponto porque é específico para listas.*
#
# *   *A função insert(posição, argumento) permite que você adicione um elemento a uma lista, em uma posição específica.*
#
# *   *A função pop() remove um elemento de uma lista.*

# %%
text = "Praticando"

print(text.lower()) # converte a string para minúsculo

print(text.upper()) # converte a string para maiúsculo

print("teste".upper()) # converte a string para maiúsculo

print(text.capitalize()) # converte primeiro caractere para maiúsculo

print(text.find("a")) # Mostra o índice do caractere

print(text.find("z")) # Retornará -1 se o caractere não existir na string

print(" Olá Mundo ".strip()) #Remove os espaços do inicio e fim, não do meio

print("Python é incrivel".split()) #Divide uma string em uma Lista de SubStrings
# Out:
# praticando
# PRATICANDO
# TESTE
# Praticando
# 2
# -1
# Olá Mundo
# ['Python', 'é', 'incrivel']

# %% [markdown]
# #### 📝 Funções de Strings
#
# *    *As funções upper() e lower() permitem que você mude rapidamente o caso de uma string para tudo em maiúsculas ou minúsculas, respectivamente.*
#
# *    *Funções que funcionam apenas em certos objetos (strings, listas, etc.) são chamadas usando a notação de ponto.<br> exemplo: "objeto.função"*
#
# *    *A função capitalize() converte primeiro caractere de uma string para maiúsculas*
#
# *    *A função find() verifica se um caractere (ou um padrão de caracteres) está presente em uma string. A função retorna o índice (posição) do valor fornecido. Se o valor fornecido estiver presente várias vezes, a função retornará a primeira ocorrência (o índice mais baixo).* <br>
# *find() retornará -1 se o valor não puder ser encontrado na string.*

# %%
x = [16, 5, 3, 9, 7]

# Soma o valor númerico
total = sum(x)
print("Soma: {}" .format(total))

# Soma a qtde de itens
total = len(x)
print(f"Quantidade de itens: {total}")

# Max() Retorna o maior valor da lista
print("Maior valor:", max(x))

# Retorna o menor valor
print("Menor valor:", min(x))

# Ordena os valores da lista
sorteio = sorted(x)
print(sorteio)

# Ordena de forma decrescente
sorteio = sorted(x, reverse=True)
print(sorteio)

# %% [markdown]
# #### 📝 Funções incorporadas
#
# * *A função sum() recebe uma lista como argumento e soma todos os elementos da lista.*
# * *A função max() retorna o valor máximo em uma lista.*
# * *A função min() retorna o valor mínimo em uma lista.*
# * *A função sorted() recebe um iterável como entrada e retorna uma list com os itens ordenados.*
# * *A função sorted() pode lidar tanto com valores numéricos quanto textuais. Para valores textuais, ela os ordena alfabeticamente.*
# * *<b>Reverse</b> Quando reverse = True, os valores são classificados em ordem decrescente.*

# %%
# Coleção imutável
tupla = (16, "Gilbert", True, 1.78, 16, "Gilbert")

print("Ocorrencias do 16:", tupla.count(16))
print("Ocorrencias da String:", tupla.count("Gilbert"))
print("Ocorrencias do 1995:", tupla.count(1995))
print()

# Descompactação
data_aniversário = (16, "março", 1995)

dia, mes, ano = data_aniversário
print(dia)
print(mes)
print(ano)
print()

dia, *resto = data_aniversário
print(dia)
print(resto)

# %% [markdown]
# #### 📝Trabalhando com tuplas
#
# * *A função count() calcula o número de ocorrências de um item em uma tupla.*
# * *O operador * na descompactação de tuplas é usado para reunir vários elementos da tupla em uma lista. Isso é útil ao lidar com tuplas de comprimento desconhecido.*

# %%
# Conjuntos coleções desordenadas mutáveis

conjunto = {"Estudando", "Python", 2025}
conjunto2 = {"Uesc", 7 > 5, "Student", 2025}
# conjuntos = {"Duplicata", "Python", "Duplicata"} # Erro Duplicata 2x

print(conjunto)
# print(conjunto[0]) # Erro! não suportam indexação ou fatiamento.

conjunto.add("Novo")
print(conjunto)

conjunto.remove("Novo")
print(conjunto)

# conjunto.append("Novo") # Erro! append só funciona em lista ordenadas

uniao = conjunto.union(conjunto2)
print(uniao)

diference = conjunto.difference(conjunto2)
print(diference)

conjunto.clear()
print(conjunto)

# %% [markdown]
# #### 📝Conjuntos
# *Coleções desordenadas mutáveis*
#
#
# * *A função clear() não aceita um argumento e remove todos os itens de um conjunto.*
# * *A função union() retorna um novo conjunto com todos os elementos de ambos os conjuntos, omitindo duplicatas.*
# * *A função difference() retorna um conjunto contendo elementos que estão apenas no primeiro conjunto e não no segundo.*
#
# ![image.png](attachment:image.png)

# %%
# Dicionário

product = {
    "name": "Caneta",
    "color": "red",
    "price": 2.99
}

# Indexação
print(product["name"])

produto = product.get("color")
print(produto)

info_keys = product.keys()
info_values = product.values()
print(info_keys)
print(info_values)

info = product.items()
print(info)

# Atribuindo valor para price
product["price"] = 1.99
print(product.items())

# Update atualiza o dicionário
product.update({"name": "Lápis"})
print(product.items())

product.update({"ano": "2025"})
print(product.items())

# Remove item usando a chave
product.pop("ano")
print(product.items())

# Verifica se chave ou valor esta no dicionário
print("price" in product)
print()

# Imprime as chaves
for i in product:
    print(i)
    
print()
    
# Imprime os valores
for i in product.values():
    print(i)

# %% [markdown]
# #### 📝Dicionário
#
# * *Dicionários são tipos de coleções usados para armazenar dados em pares de chave:valor, que são considerados como itens. Eles são ideais para organizar dados em pares, onde cada pedaço de dado (valor) tem seu identificador único (chave).*
# * *índdice: Para acessar valores em dicionários, precisa usar as keys.*
# * *A função get() acessa valores em um dicionário*
# * *A função values() e keys() obtem todos os valores e chaves de um dicionário*
# * *A função items() retorna todos os pares de chave:valor em um dicionário.*
# * *A função update() mudar ou adicionar itens ao dicionário.*
#
# ![image.png](attachment:image.png)

# %%
# Compreensão de Listas
nums = [i for i in range(1, 21)]
print(nums)

# Dobra os valores
nums = [i * 2 for i in range(10)]
print(nums)

# %% [markdown]
# #### 📝Compreensão de Lista
#
# * *List comprehensions são atalhos úteis para tais operações. Eles oferecem uma maneira mais curta e legível de criar listas com várias configurações usando apenas uma única linha de código.*<br>
#
#
# ![image.png](attachment:image.png)
