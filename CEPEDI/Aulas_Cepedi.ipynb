# %% [markdown]
# - CONECTA E CAPACITA – PARCERIA CEPEDI - IFBA <br>
# - CURSO DE DESENVOLVIMENTO BACK-END COM PYTHON <br>
# - MÓDULO 1 - LÓGICA DE PROGRAMAÇÃO COM PYTHON <br>
# - PROFESSORA KARINE PRADO <br>
# - Aluno: Gilbert Carmo Macedo <br>

# %%
# Primeira atividade - CEPEDI 04/09/25


# !Apresentação da disciplina
print('Hello World!')

# !Atribuindo Variavel
nome = input('digite seu nome? ')
nome2 = input('Digite o sobrenome? ')

# !Printando dado armazenado na variavel
# três formas diferentes
print('meu nome é {} e sobrenome {}, td bem?' .format(nome, nome2))
print('Meu nome é', nome)
print(f'meu nome é {nome}')

# !identificando o tipo da variavel
print(type(nome))

# !Operação de inteiros
a = input('Digite um digito? ')
b = input('Digite outro digito? ')
resposta = a + b

x = int(input('digite um digito ?'))
y = int(input('digite outro digito ?'))
resultado = x + y

# Concatenando as variaveis a e b
print('Concatenação de caracteres:', resposta)

# Fazendo casting da variavel para inteiro
print('a soma dos resultados é', resultado)

# !Concantenação de prints
print('Olá ', nome, sep='', end='')
print(' Macedo!')


nome = input('Digite seu nome? ')
idade = int(('digite sua idade? '))
peso = float(input('Digite seu peso? '))
altura = float(input('Digite sua altura? '))

print(f'Olá {nome}, você tem {idade} anos, pesa {peso}kg, e tem {altura} de altura')

# %%
# Segunda Atividade Prática 08/09/2025

Nota1 = float(input('Digite a primeira nota? '))
Nota2 = float(input('Digite a segunda nota? '))

media = (Nota1 + Nota2) / 2

print(f'A media do aluno é: {media}')

# %%
# Terceira Atividade Prática

n1 = float(input('Digite um digito? '))
n2 = float(input('Digite outro digito? '))

soma = n1 + n2
dif = n1 - n2
prod = n1 * n2
div = n1 / n2
div_int = n1 // n2
resto = n1 % n2
resp = n1 ** n2

print(f' {soma}\n {dif}\n {prod}\n {div}\n {div_int}\n {resto}\n {resp}')

# %%
# Quarta Atividade Prática

idade = int(input('Digite sua idade? '))

if idade > 18:
    print('Maior de idade?', {idade>18})
elif idade < 18:
    print('Menor de idade?', {idade<18})
else:
    print('Tem exatamente 18 anos?', {idade == 18})

# %%
# Quinta Atividade Prática

cnh = input("O condutor possui CNH (True/False? ")
idade = int(input("Digite a idade? "))

possui_cnh = cnh.strip().lower() == 'true'

if possui_cnh and idade >= 18:
    print('Usuario é maior de idade e tem CNH?', True)
else:
    print('Usuário atende aos requisitos:', False)

print(bool(possui_cnh))

# %%
# Sexta Atividade Prátic

num = float(input('Digite um digito: '))

if num >= 0:
    print(f'{num: .2f} é positivo!!!')
else:
    print(f'{num: .2f} é negativo!!!')

# %%
# Sétima Atividade Prática

num = int(input('Informe um digito: '))

if num % 2 == 0:
    print(f'{num} é Par!!!')
else:
    print(f'{num} é Ímpar!!!')
    
hora = int(input('digite as horas: '))

if hora >= 0 and hora <= 12:
    print('Bom dia!!!')
elif hora >= 12 and hora <= 18:
    print('Boa Tarde!!!')
else:
    print('Boa Noite!!!')
    
    
nome = input('Digite um nome de usuario: ')

if nome == '':
    print('Nome não pode ser vazio')
else:
    print(nome)

# %%
# Oitava Atividade Prática

import getpass
import pwinput

user = input('Digite o nome de usuário: ')
#senha = getpass.getpass("Digite sua senha: ")  #Oculta a senha da tela
senha = pwinput.pwinput("Digite sua senha: ")

user_id = 'admin'
senha_id = '12345'

if user_id == user and senha_id == senha:
    print('Login Bem-Sucedido')
else:
    print('Usuario ou Senha incorreta!')

# %%
# Nona Atividade Prática

num = int(input('digite um numero: '))

if num % 3 == 0 and num % 5 == 0:
    print(f'{num} é multiplo de 3 e 5')
elif num % 5 == 0:
    print(f'{num} é multiplo de 5')
elif num % 3 == 0:
    print(f'{num} é multiplo de 3')
else:
    print('Não é multiplo de 3 e 5')

# %%
# Décima Atividade Prática

num = int(input('digite um valor: '))
i = 1

while i <= num:
    
    print(i)
    i += 1
    

soma = 0
cont = -1

n1 = -1

while n1 != 0:
    n1 = int(input('digite um digito (0 para encerrar e obter a média): '))
    soma += n1
    cont += 1

print(f'Media: {soma / cont}')

# %%
# Décima Primeira Atividade
# Exercícios Laço de Repetição For

inicio = 1
fim = 10
passo = 2


for i in range(inicio, fim, passo):
    print(i)

print()    

#Programa que imprima os multiplos de 5, de 0 até 25
for i in range(0, 26, 5):
    print(i)
    
print('')
    
#Programa que imprime a tabuada de 3
for i in range(11):
   print('3x{} = {}' .format(i, 3*i)) 

print()    

for i in range(1, 6):
    for j in range(1, 6):
        print(f'{i} x {j} = {i * j}')
    
    print()

# %%
# Décima Segunda Atividade

numeros = [10, 20, 30, 40, 50, 60, 70]

print(numeros[1:4])   # [20, 30, 40] 
print(numeros[:3])    # [10, 20, 30] 
print(numeros[::2])   # [10, 30, 50] 
print(numeros[::-1])  # [60, 50, 40, 30, 20, 10] (lista invertida) 

# Crie uma lista com os nomes de 4 
# colegas da sala. Adicione um novo 
# nome no final com append() e outro no 
# início com insert().

# %%
# Décima Terceira Atividade Prática

lista = []

for i in range(6):
    i = int(input("Digite 6 digitos: "))
    
    lista.append(i)
    
print(lista)

print('Os 3 primeiros elementos: ', lista[:3])
print('Os 3 ultimos elementos: ', lista[3:])
print('Elementos partir do segundo até o quarto:', lista[1:4])
print('Lista Invertida', lista[::-1])
print('O ultimo e o primeiro elemento', lista[::-5])
print('O primeiro e o ultimo elemento', lista[::5])

# %%
# Décima Quarta Atividade Prática

d_semanas = ("Domingo", "Segunda", "Terça", "Quarta", "Quinta", "Sexta", "Sábado")

print(d_semanas)

#Dicionário

livros = {
    "Titulo": "Diário de Anny Frank",
    "Autor": "Anny",
    "NumPage": 50
}

'''for chave, valor in livros.items():
    print(f'{chave}: {valor}')'''
    

livros.update({"Titulo": "A Morte como Despertar"})
livros.update({"Editora": "Amazon"})

for chave, valor in livros.items():
    print(f'{chave}: {valor}')

print(livros.items())

# %%
# Décima Quinta Atividade Prática

'''def soma(n1, n2):
    resultado = n1 + n2
    return resultado

cal = soma("a", "b") # !Concatenação
cal2 = soma(5, 5) # !Soma

print()
print(f'Concatenção de Strings: {cal}\n')
print(f'Soma de inteiros: {cal2}\n')

# !Função com valor padrão no parametro
def saudacao(nome="Amigo"):
    print(f'Olá, {nome}')
    
saudacao() # !Saudação sem parametro
saudacao("Gilbert")

def recebe_lista(lista):
    print(lista)
   
l = [1,2,3] 
recebe_lista(l)

def cria_lista(tam):
    lista = []
    for i in range(tam):
        dig = int(input(f'Digite o {i+1}° de {tam} digitos: '))
        lista.append(dig)
        
    return lista

lista = cria_lista(5)

print(lista)'''

# Atividade

def media(n1, n2):
    return (n1 + n2) / 2
    
entrada = input("Digite dois numeros separados por espaço: ")
nt1, nt2 = entrada.split()
nt1 = float(nt1)
nt2 = float(nt2)

result = media(nt1, nt2)

print(f'A media é: {result}')

def verificar_situacao(media):
    if result >= 7:
        print('Aluno Aprovado!')
    elif result >= 5 and result <= 6.9:
        print('Aluno em Recuperação!')
    else:
        print('Aluno Reprovado!')


verificar_situacao(result)

def calcular_salario(hs_trab, val_hs):
    return hs_trab * val_hs

hs_trab = int(input('Digite as hs trabalhadas: '))
val_hs = float(input('Digite o valor hora: '))

calculo = calcular_salario(hs_trab, val_hs)

print(f'O Salário é: R$: {calculo}')

# %%
# Décima Sexta Atividade Prática

stop = 'True'
soma = 0

while stop.strip().lower() == 'true':
    num1 = int(input('Digite um numero: '))
    num2 = int(input('Digite outro numero: '))
    
    soma += (num1 + num2)
    
    stop = input("Deseja Sair (True/False): ")
    

print(f'Resultado: {soma}')

# %%
# Tema: Tratatamento de Exceções Utilizando Try Exception 06/10/25

try:
    n1 = int(input('Informe um número inteiro: '))
    n2 = int(input('Informe um número inteiro: '))
    result = n1/n2
except ValueError:
    print("Digite apenas números inteiros: ")
except ZeroDivisionError:
    print("Não é possível dividir por zero.")
else:
    print("Resultado:", result)
# Out:
# Digite apenas números inteiros:

# %%
# Vigésima Atividade Prática 06/10/25
def verificar_idade(idade):
    if idade < 0:
        raise ValueError('A Idade não pode ser negativa!')
    else:
        return True


try:
    idade = int(input('Digite sua idade: '))
    if verificar_idade(idade):
        print('Idade Ok!')
except ValueError as e:
    print(e)
# Out:
# <class 'ValueError'>

# %%
# A Construção básica para tratar exceções

try:
    # Código que pode gerar exceção
except TipoDaExcecao:
    # Tratamento especifico
except (tipo 1, tipo 2) as e:
